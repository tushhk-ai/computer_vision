# %%
import cv2, glob,os
from matplotlib import pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score,confusion_matrix
import skimage
from skimage.filters import sobel_h,sobel
import warnings
warnings.filterwarnings('ignore')
from keras.preprocessing.image import img_to_array
from keras.models import load_model
import numpy as np
# %matplotlib inline

# %%
img = cv2.imread('/home/tusharkalyani/Documents/UPMC/pelvis/000_400_Hips_Extracted/1_pelvis_left.jpg')

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (450, 450, 3)

# %%
mask=np.full((450,450),0)

# %%
plt.imshow(mask)

# %%
img = cv2.imread('/home/tusharkalyani/Documents/UPMC/pelvis/000_400_Hips_Extracted/3_frog_right.jpg')

# %%
circle=cv2.circle(img, (225,225),200,(255,255,255),-1 )

# %%
plt.imshow(circle)

# %%
img = cv2.imread('/home/tusharkalyani/Documents/UPMC/pelvis/000_400_Hips_Extracted/3_frog_right.jpg')

# %%
radius = 220
center = (225,225)
axes = (radius, radius)
angle = 0
startAngle = 210
endAngle = 210+240
thickness = -1
half=cv2.ellipse(img, center, axes, angle, startAngle, endAngle, (255,255,255), thickness)

# %%
plt.imshow(half)

# %%
img = cv2.imread('/home/tusharkalyani/Documents/UPMC/pelvis/000_400_Hips_Extracted/3_frog_right.jpg')

# %%
radius = 220
center = (225,225)
axes = (radius, radius)
angle = 0
startAngle = 210
endAngle = 210+80
thickness = -1
half=cv2.ellipse(img, center, axes, angle, startAngle, endAngle, (255,255,255), thickness)

# %%
plt.imshow(half)

# %%
img = cv2.imread('/home/tusharkalyani/Documents/UPMC/pelvis/000_400_Hips_Extracted/3_frog_right.jpg')

# %%
radius = 220
center = (225,225)
axes = (radius, radius)
angle = 0
startAngle = 210+70
endAngle = 210+70+80
thickness = -1
half=cv2.ellipse(img, center, axes, angle, startAngle, endAngle, (255,255,255), thickness)

# %%
plt.imshow(half)

# %%
img = cv2.imread('/home/tusharkalyani/Documents/UPMC/pelvis/000_400_Hips_Extracted/3_frog_right.jpg')

# %%
radius = 220
center = (225,225)
axes = (radius, radius)
angle = 0
startAngle = 210+70+80
endAngle = 210+70+80+80
thickness = -1
half=cv2.ellipse(img, center, axes, angle, startAngle, endAngle, (255,255,255), thickness)

# %%
plt.imshow(half)

# %%
mask=np.full((450,450),0,dtype=np.uint8)

# %%
plt.imshow(np.array(mask))

# %%
radius = 220
center = (225,225)
axes = (radius, radius)
angle = 0
startAngle = 210
endAngle = 210+80
thickness = -1
zone1=cv2.ellipse(mask, center, axes, angle, startAngle, endAngle, (255,255,255), thickness)

# %%
plt.imshow(np.array(zone1))

# %%
plt.imshow(img)

# %%
fg = cv2.bitwise_or(img,img, mask=zone1)

# %%
plt.imshow(fg)

# %%
cv2.imwrite('/home/tusharkalyani/Documents/UPMC/pelvis/ROI_masking/zone1_mask.jpg',zone1)
# Out:
# True

# %%
mask=np.full((450,450),0,dtype=np.uint8)

# %%
radius = 220
center = (225,225)
axes = (radius, radius)
angle = 0
startAngle = 210+70
endAngle = 210+70+80
thickness = -1
zone2=cv2.ellipse(mask, center, axes, angle, startAngle, endAngle, (255,255,255), thickness)

# %%
plt.imshow(np.array(zone2))

# %%
cv2.imwrite('/home/tusharkalyani/Documents/UPMC/pelvis/ROI_masking/zone2_mask.jpg',zone2)
# Out:
# True

# %%
mask=np.full((450,450),0,dtype=np.uint8)

# %%
radius = 220
center = (225,225)
axes = (radius, radius)
angle = 0
startAngle = 210+70+70
endAngle = 210+70+70+80
thickness = -1
zone3=cv2.ellipse(mask, center, axes, angle, startAngle, endAngle, (255,255,255), thickness)

# %%
plt.imshow(np.array(zone3))

# %%
cv2.imwrite('/home/tusharkalyani/Documents/UPMC/pelvis/ROI_masking/zone3_mask.jpg',zone3)
# Out:
# True

# %%
mask=np.full((450,450),0,dtype=np.uint8)

# %%
radius = 220
center = (225,225)
axes = (radius, radius)
angle = 0
startAngle = 210
endAngle = 210+70+70+80
thickness = -1
full_zone=cv2.ellipse(mask, center, axes, angle, startAngle, endAngle, (255,255,255), thickness)

# %%
plt.imshow(full_zone)

# %%
pimg = cv2.imread('/home/tusharkalyani/Documents/UPMC/pelvis/000_400_Hips_Extracted/37_pelvis_left.jpg')

# %%
masked_pimg = cv2.bitwise_or(pimg,pimg, mask=full_zone)

# %%
plt.imshow(masked_pimg)

# %%
fimgl = cv2.imread('/home/tusharkalyani/Documents/UPMC/pelvis/000_400_Hips_Extracted/163_frog_left.jpg')

# %%
masked_fimgl = cv2.bitwise_or(fimgl,fimgl, mask=full_zone)

# %%
plt.imshow(masked_fimgl)

# %%
fimgr = cv2.imread('/home/tusharkalyani/Documents/UPMC/pelvis/000_400_Hips_Extracted/14_frog_right.jpg')

# %%
masked_fimgr = cv2.bitwise_or(fimgr,fimgr, mask=full_zone)

# %%
plt.imshow(masked_fimgr)

# %%
pimgl = cv2.imread('/home/tusharkalyani/Documents/UPMC/pelvis/000_400_Hips_Extracted/27_pelvis_right.jpg')

# %%
masked_pimgl = cv2.bitwise_or(pimgl,pimgl, mask=full_zone)

# %%
plt.imshow(masked_pimgl)
